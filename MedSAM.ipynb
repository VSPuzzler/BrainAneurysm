# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/11thGrade/Research/MedSAM
# Out:
# /content/drive/MyDrive/11thGrade/Research/MedSAM

# %%
# !pip install monai matplotlib scikit-image SimpleITK>=2.2.1 nibabel tqdm scipy ipympl opencv-python jupyterlab ipywidgets connected-components-3d

# %%
# !python train_one_gpu.py
# Out:
# 2024-01-02 01:38:22.239705: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-02 01:38:22.239751: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-02 01:38:22.242000: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-02 01:38:23.438833: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# number of images: 2191
# torch.Size([8, 3, 1024, 1024]) torch.Size([8, 1, 1024, 1024]) torch.Size([8, 4])
# ./work_dir/MedSAM-ViT-B-20240102-0138
# Number of total parameters:  93735472
# Number of trainable parameters:  93729252
# ...
